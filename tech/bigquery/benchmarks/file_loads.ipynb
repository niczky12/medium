# %% [markdown]
# <a href="https://colab.research.google.com/github/niczky12/medium/blob/bq_file_loads/tech/bigquery/benchmarks/file_loads.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
